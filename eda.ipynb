# %% [markdown]
# # =========================
# # Notebook 2: EDA & Visualization
# # =========================

# %%
# Step 1: Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Step 2: Load cleaned dataset
df = pd.read_csv("/Users/sangsthitapanda/Desktop/L&T PROJECT/archive/employee_attrition_dataset_cleaned.csv")
df.head()
# Out:
#    employee_id  age  gender  marital_status  department  job_role  job_level  \
# 0            1   58       0               1           2         3          1
# 1            2   48       0               1           4         1          5
# 2            3   34       1               1           3         1          1
# 3            4   27       0               0           3         3          1
# 4            5   40       1               0           3         2          1
#
#    monthly_income  hourly_rate  years_at_company  ...  overtime  \
# 0           15488           28                15  ...         0
# 1           13079           28                 6  ...         1
# 2           13744           24                24  ...         1
# 3            6809           26                10  ...         0
# 4           10206           52                29  ...         0
#
#    project_count  average_hours_worked_per_week  absenteeism  \
# ...

# %%
# Step 3: Target distribution
sns.countplot(x="attrition", data=df)
plt.title("Attrition Distribution")
plt.show()

attrition_rate = df["attrition"].mean() * 100
print(f"Attrition Rate: {attrition_rate:.2f}%")
# Out:
# Attrition Rate: 18.90%

# %%
# Step 4: Demographics
plt.figure(figsize=(8,5))
sns.histplot(df["age"], bins=20, kde=True)
plt.title("Age Distribution of Employees")
plt.show()

sns.boxplot(x="attrition", y="age", data=df)
plt.title("Attrition by Age")
plt.show()

sns.countplot(x="gender", hue="attrition", data=df)
plt.title("Attrition by Gender")
plt.show()

sns.countplot(x="marital_status", hue="attrition", data=df)
plt.title("Attrition by Marital Status")
plt.show()

# %%
# Step 5: Job & Income
plt.figure(figsize=(10,6))
sns.countplot(x="department", hue="attrition", data=df)
plt.title("Attrition by Department")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(12,6))
sns.countplot(x="job_role", hue="attrition", data=df)
plt.title("Attrition by Job Role")
plt.xticks(rotation=45)
plt.show()

sns.boxplot(x="attrition", y="monthly_income", data=df)
plt.title("Monthly Income vs Attrition")
plt.show()

sns.countplot(x="overtime", hue="attrition", data=df)
plt.title("Overtime vs Attrition")
plt.show()

# %%
# Step 6: Performance & Satisfaction
sns.countplot(x="job_satisfaction", hue="attrition", data=df)
plt.title("Attrition vs Job Satisfaction")
plt.show()

sns.countplot(x="work_life_balance", hue="attrition", data=df)
plt.title("Attrition vs Work Life Balance")
plt.show()

sns.countplot(x="performance_rating", hue="attrition", data=df)
plt.title("Attrition vs Performance Rating")
plt.show()

sns.countplot(x="work_environment_satisfaction", hue="attrition", data=df)
plt.title("Attrition vs Work Environment Satisfaction")
plt.show()

# %%
# Step 7: Tenure & Career Progression
sns.boxplot(x="attrition", y="years_at_company", data=df)
plt.title("Years at Company vs Attrition")
plt.show()

sns.boxplot(x="attrition", y="years_since_last_promotion", data=df)
plt.title("Years Since Last Promotion vs Attrition")
plt.show()

sns.boxplot(x="attrition", y="distance_from_home", data=df)
plt.title("Distance from Home vs Attrition")
plt.show()

# %%
# Step 8: Correlation Heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), cmap="coolwarm", annot=False)
plt.title("Correlation Heatmap")
plt.show()
